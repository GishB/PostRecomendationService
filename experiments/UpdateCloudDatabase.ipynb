# %% [markdown]
# # Note:
#     Store features on the cloud

# %% [markdown]
# # Import libs

# %%
import os, sys
import pickle

import pandas as pd
import numpy as np
from joblib import dump, load
# import texthero
from sklearn.feature_extraction.text import TfidfVectorizer
from sqlalchemy import create_engine

sys.path.append("..")
from others.database import SessionLocal, engine
from sqlalchemy import desc, func, asc
from others.schema import FeedGet, PostGet, UserGet
from others.table_post import Post
from others.table_user import User
from others.table_feed import Feed

import matplotlib.pyplot as plt

# %% [markdown]
# # Import data

# %%
df_users = pd.read_parquet('df_users_embedings.parquet')
df_posts = pd.read_parquet('df_posts_new_features_and_post.parquet')

# %%
df_users.rename(columns={"id":"user_id"}, inplace=True)

# %% [markdown]
# # Save data on the cloud

# %%
def load_data_users(df, engine) -> int:
    chunksize = 200000
    return df.to_sql(name='aleksandr_samofalov_features_lesson_22_users_october_2023',
                  con=engine, chunksize=chunksize, if_exists='replace')

def load_data_post(df, engine) -> int:
    chunksize = 200000
    return df.to_sql(name='aleksandr_samofalov_features_lesson_22_post_october_2023',
                  con=engine, chunksize=chunksize, if_exists='replace')

# %%
load_data_users(df_users, engine)
# Out:
# 205

# %%
load_data_post(df_posts, engine)
# Out:
# 23

# %% [markdown]
# # Check saved data

# %%
def batch_load_sql(query: str, engine: object) -> pd.DataFrame:
    CHUNKSIZE = 200000
    conn = engine.connect().execution_options(stream_results=True)
    chunks = []
    for ind, chunk_dataframe in enumerate(pd.read_sql(query, conn, chunksize=CHUNKSIZE)):
        print(chunk_dataframe.shape)
        print(ind)
        chunks.append(chunk_dataframe)
    conn.close()
    return pd.concat(chunks, ignore_index=True)

# %%
def load_features_post() -> pd.DataFrame:
    engine = create_engine(
    "postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
    "postgres.lab.karpov.courses:6432/startml"
    )
    df_post_data = batch_load_sql("""SELECT * FROM aleksandr_samofalov_features_lesson_22_post_october_2023""", engine)
    df_post_data = df_post_data.drop(['index'], axis=1)
    return df_post_data


def load_features() -> pd.DataFrame:
    engine = create_engine(
    "postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
    "postgres.lab.karpov.courses:6432/startml"
    )
    df_user_data = batch_load_sql("""SELECT * FROM aleksandr_samofalov_features_lesson_22_users_october_2023""", engine)
    df_user_data = df_user_data.drop(['index'], axis=1)
    return df_user_data

# %%
load_features_post()
# Out:
# (7023, 26)
# 0
#       post_id  topic_covid  topic_entertainment  topic_movie  topic_politics  \
# 0           1        False                False        False           False
# 1           2        False                False        False           False
# 2           3        False                False        False           False
# 3           4        False                False        False           False
# 4           5        False                False        False           False
# ...       ...          ...                  ...          ...             ...
# 7018     7315        False                False         True           False
# 7019     7316        False                False         True           False
# 7020     7317        False                False         True           False
# 7021     7318        False                False         True           False
# 7022     7319        False                False         True           False
#
#       topic_sport  topic_tech  kmean_label  DistanceToCluster_0  \
# 0           False       False            2             3.729024
# 1           False       False            2             3.531465
# 2           False       False            2             3.538897
# 3           False       False           10             3.031447
# 4           False       False           10             3.280477
# ...           ...         ...          ...                  ...
# 7018        False       False            7             2.336807
# 7019        False       False            7             2.197449
# 7020        False       False            7             2.626637
# 7021        False       False            6             1.975253
# 7022        False       False           13             2.408587
#
#       DistanceToCluster_1  ...  DistanceToCluster_7  DistanceToCluster_8  \
# 0                2.998742  ...             3.417403             3.373112
# 1                2.843195  ...             3.323233             3.324048
# 2                3.058267  ...             3.348733             3.265760
# 3                3.260913  ...             3.731672             3.517551
# 4                2.642357  ...             2.803656             3.028448
# ...                   ...  ...                  ...                  ...
# 7018             2.816310  ...             1.283884             3.135332
# 7019             2.500667  ...             0.940390             2.930152
# 7020             2.534971  ...             1.491582             2.834718
# 7021             3.106200  ...             1.489237             3.432551
# 7022             2.980180  ...             2.140690             3.295767
#
#       DistanceToCluster_9  DistanceToCluster_10  DistanceToCluster_11  \
# 0                2.350711              1.900091              2.218462
# 1                2.316050              2.180061              2.233397
# 2                2.390932              1.806858              3.036396
# 3                2.811656              2.429931              3.393587
# 4                2.009257              1.457895              2.923765
# ...                   ...                   ...                   ...
# 7018             2.738250              3.003807              3.355360
# 7019             2.448724              2.967479              3.189711
# 7020             2.810127              3.188147              3.403540
# 7021             2.991727              3.197914              3.443767
# 7022             2.906321              3.318611              3.563085
#
#       DistanceToCluster_12  DistanceToCluster_13  DistanceToCluster_14  \
# 0                 2.839048              3.461114              3.412472
# 1                 2.555996              3.138126              3.218686
# 2                 2.888302              3.141400              3.283395
# 3                 3.379051              3.792460              3.695954
# 4                 2.129916              2.764996              2.838905
# ...                    ...                   ...                   ...
# 7018              2.330962              1.821759              2.005075
# 7019              2.229802              1.843959              1.767640
# 7020              2.444165              1.992768              2.170022
# 7021              2.307946              1.514832              1.855331
# 7022              2.674964              1.774178              2.107236
#
#                                                    text     topic
# 0     UK economy facing major risks\n\nThe UK manufa...  business
# 1     Aids and climate top Davos agenda\n\nClimate c...  business
# 2     Asian quake hits European shares\n\nShares in ...  business
# 3     India power shares jump on debut\n\nShares in ...  business
# 4     Lacroix label bought by US firm\n\nLuxury good...  business
# ...                                                 ...       ...
# 7018  OK, I would not normally watch a Farrelly brot...     movie
# 7019  I give this movie 2 stars purely because of it...     movie
# 7020  I cant believe this film was allowed to be mad...     movie
# 7021  The version I saw of this film was the Blockbu...     movie
# 7022  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 25 columns]

# %%
load_features()
# Out:
# (163205, 22)
# 0
#         user_id  gender  age  Belarus  Cyprus  Estonia  Finland  Kazakhstan  \
# 0           200       1   34    False   False    False    False       False
# 1           201       0   37    False   False    False    False       False
# 2           202       1   17    False   False    False    False       False
# 3           203       0   18    False   False    False    False       False
# 4           204       0   36    False   False    False    False       False
# ...         ...     ...  ...      ...     ...      ...      ...         ...
# 163200   168548       0   36    False   False    False    False       False
# 163201   168549       0   18    False   False    False    False       False
# 163202   168550       1   41    False   False    False    False       False
# 163203   168551       0   38    False   False    False    False       False
# 163204   168552       1   16    False   False    False    False       False
#
#         Latvia  Russia  ...  Turkey  Ukraine  exp_1  exp_2  exp_3  exp_4  \
# 0        False    True  ...   False    False  False  False   True  False
# 1        False    True  ...   False    False  False  False  False  False
# 2        False    True  ...   False    False  False  False  False   True
# 3        False    True  ...   False    False   True  False  False  False
# 4        False    True  ...   False    False  False  False   True  False
# ...        ...     ...  ...     ...      ...    ...    ...    ...    ...
# 163200   False    True  ...   False    False  False  False  False   True
# 163201   False    True  ...   False    False  False   True  False  False
# 163202   False    True  ...   False    False  False  False  False   True
# 163203   False    True  ...   False    False  False  False   True  False
# 163204   False    True  ...   False    False  False  False  False   True
#
#         Android    iOS    ads  organic
# 0          True  False   True    False
# 1          True  False   True    False
# 2          True  False   True    False
# 3         False   True   True    False
# 4          True  False   True    False
# ...         ...    ...    ...      ...
# 163200     True  False  False     True
# 163201     True  False  False     True
# 163202     True  False  False     True
# 163203    False   True  False     True
# 163204     True  False  False     True
#
# [163205 rows x 21 columns]
